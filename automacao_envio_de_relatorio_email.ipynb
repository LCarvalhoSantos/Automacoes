# %%
import pyautogui
import pyperclip
import time
import pandas
from datetime import date

#INICIANDO AUTOMAÇÃO
pyautogui.PAUSE = 1
pyautogui.alert("Iniciando automação! Aperte OK e aguarde!")
# Out:
# 'OK'

# %%
#ABRINDO GMAIL NO NAVEGADOR
pyautogui.hotkey("ctrl","t")
link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing"
pyperclip.copy(link)
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")

time.sleep(5)

# %%
#SELECIONANDO ARQUIVO E FAZENDO DOWNLOAD
pyautogui.click(x=336 ,y=293, clicks=2)
time.sleep(3)

pyautogui.click(x=336 ,y=293, button="right")
time.sleep(3)

pyautogui.click(x=444 ,y=629)
time.sleep(3)

# %%
#ABRINDO TABELA E EXTRAINDO DADOS
tabela = pandas.read_excel(r"C:\Users\Lucas\Downloads\Vendas - Dez.xlsx")
display(tabela)

fat = float(tabela["Valor Final"].sum())
qtde = tabela["Quantidade"].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#ABRINDO SITE PARA ENVIAR EMAIL
pyautogui.hotkey("ctrl","t")
gmail = "https://mail.google.com/mail/u/0/#inbox"
pyperclip.copy(gmail)
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")

# %%
#ADICIONANDO EMAIL DE ENVIO
time.sleep(1)
pyautogui.click(x=55 ,y=206)
email = "lucas.santos276@fatec.sp.gov.br"
pyperclip.copy(email)
pyautogui.hotkey("ctrl","v")
pyautogui.press("tab")

# %%
#INSERINDO ASSUNTO NO EMAIL
assunto = "Relatório diário"
pyperclip.copy(assunto)
pyautogui.hotkey("ctrl","v")
pyautogui.press("tab")

# %%
#INSERINDO CORPO DO TEXTO
data = date.today()
texto = ("""Bom dia diretoria.
Segue os rendimentos e quantidade de itens vendidos no dia {}
Faturamento: {}
Quantidade: {}

Abs...""".format(data,fat,qtde))

# %%
#ENVIANDO EMAIL
pyperclip.copy(texto)
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("ctrl","enter")
